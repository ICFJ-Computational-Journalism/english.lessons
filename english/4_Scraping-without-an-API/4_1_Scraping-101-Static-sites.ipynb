# %% [markdown]
# ## Scraping w/o an API

# %% [markdown]
# #### What is scraping?
#
# Scraping is the process of using code to automatically collect data from websites. It's like having a robot do the work of copying and pasting information from different pages on a website, except the robot is a program that we write.
#
# #### Why do people do scraping?
#
# People scrape websites for various reasons, such as market research, lead generation, content creation, and data analysis. It's a way to gather large amounts of data quickly and efficiently. One of the key benefits of web scraping in journalism is the ability to gather data for investigative reporting. Journalists can scrape data from government databases, corporate websites, and other sources to uncover hidden information and identify potential sources for stories. Additionally, web scraping can help journalists identify patterns and trends that might not be immediately apparent, as well as monitor news and social media for breaking stories, trends, or conversations around particular topics. This data can be used to create data visualizations that help readers understand complex information, as well as fact-check statements made by politicians or other public figures. Overall, web scraping is a powerful tool for journalists to collect and analyze data, uncover stories, and hold those in power accountable.
#
# Here are some examples of some projects that involve web scraping:
# 1. Analyzing Political Campaign Finance: An investigative journalist might use web scraping to collect data on campaign finance reports of political candidates and parties to uncover patterns of financial support.
# 2. Mapping the Real Estate Market: A data journalist might use web scraping to gather information from real estate websites to analyze trends in property prices and rental rates in different parts of the country.
# 3. Tracking Health Statistics: A health reporter might use web scraping to collect data on public health indicators, such as vaccination rates or hospital admissions, to monitor trends and identify potential areas of concern.
# 4. Monitoring Environmental Risks: An environmental journalist might use web scraping to collect data on pollution levels and environmental hazards, such as industrial emissions or toxic waste sites, to track the impact of industry on the environment.
# 5. Investigating Social Media Networks: An investigative journalist might use web scraping to collect data on social media activity, such as hashtag trends and user behavior, to uncover potential connections between political groups or individuals.
#
#
#
#
# #### What are some of the different methods?
#
# In Python, there are two main ways to scrape webpages: using Beautiful Soup for static pages or using Selenium for dynamic pages. Beautiful Soup is a library that can extract data from HTML tags, while Selenium can things we do in the browser such as clicking and filling out forms. Beautiful Soup is simpler to use, but Selenium is more flexible for scraping dynamic pages. Here, we will cover methods for scraping static sites.
#
#
# #### What are the hurdles?
#
# Scraping can be a complex and challenging task, and there are several hurdles to consider, including:
#
# 1. Legal issues: Scraping can violate website terms of service and may be illegal in some cases.
# 2. Anti-scraping measures: Websites may use anti-scraping measures, such as CAPTCHAs, to prevent scraping.
# 3. Data quality: Scraped data may be incomplete, inaccurate, or outdated.
# 4. Website changes: Websites may change their structure or content, which can break scraping scripts and require updates.
# 5. Performance issues: Scraping large amounts of data can be resource-intensive and may cause performance issues for the scraping tool or website being scraped.

# %% [markdown]
# #### Retrieving & Examining HTML Code

# %% [markdown]
# Suppose we have a set of links for IMDb pages that each corresponds to a different movie. How do we extract the titles of those movies?
#
# The first step is to write code to obtain the HTML page for a movie. We can use the requests library for this.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.imdb.com/title/tt0133093/'
response = requests.get(url)

html = response.content
display(html)
# Out:
# b'<html>\r\n<head><title>403 Forbidden</title></head>\r\n<body>\r\n<center><h1>403 Forbidden</h1></center>\r\n</body>\r\n</html>\r\n'

# %% [markdown]
# We run into an issue here where the website detects that we are not accessing it through a web browser and blocks our request, so we get a "Forbidden" message. We can modify the header of our request so it appears to be coming from a browser:

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
response = requests.get(url, headers=headers)
html = response.content
display(html)
# Out:
# b'<!DOCTYPE html><html lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEventListener(\'load\', (event) => {\n        if (typeof window.csa !== \'undefined\' && typeof window.csa === \'function\') {\n            var csaLatencyPlugin = window.csa(\'Content\', {\n                element: {\n                    slotId: \'LoadTitle\',\n                    type: \'service-call\'\n                }\n            });\n            csaLatencyPlugin(\'mark\', \'clickToBodyBegin\', 1683211623701);\n        }\n    })</script><title>The Matrix (1999) - IMDb</title><meta name="description" content="The Matrix: Directed by Lana Wachowski, Lilly Wachowski. With Keanu Reeves, Laurence Fishburne, Carrie-Anne Moss, Hugo Weaving. When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence." data-id="main"/><meta name="keywords" content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsis, Trailers, Credits"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"Movie","url":"/title/tt0133093/","name":"The Matrix","image":"https://m.media-amazon.com/images/M/MV5BNzQzOTk3OTAtNDQ0Zi00ZTVkLWI0MTEtMDllZjNkYzNjNTc4L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_.jpg","description":"When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.","review":{"@type":"Review","itemReviewed":{"@type":"CreativeWork","url":"/title/tt0133093/"},"author":{"@type":"Person","name":"acedj"},"dateCreated":"2019-11-01","inLanguage":"English","name":"Just wow","reviewBody":"When this came out, I was living with a roommate. He went out and saw it, came home and said, &quot;Dude, you have to go see The Matrix.&quot; So we left and he sat through it a second time. This movie is splendidly done. The mystery about what the Matrix is, unravels and you see a dystopian future unlike any we as a race would want. I have watched this over and over and never tire of it. Everyone does a great job acting in this, the special effects are above par and the story is engaging.","reviewRating":{"@type":"Rating","worstRating":1,"bestRating":10,"ratingValue":10}},"aggregateRating":{"@type":"AggregateRating","ratingCount":1950948,"bestRating":10,"worstRating":1,"ratingValue":8.7},"contentRating":"R","genre":["Action","Sci-Fi"],"datePublished":"1999-03-31","keywords":"artificial reality,war with machines,simulated reality,dystopia,post apocalypse","trailer":{"@type":"VideoObject","name":"Theatrical Trailer","embedUrl":"https://www.imdb.com/video/imdb/vi1032782617","thumbnail":{"@type":"ImageObject","contentUrl":"https://m.media-amazon.com/images/M/MV5BNDQ4NTRmN2ItYjgzMS00MzY3LWEwNmYtYmE2ODllZDdhNGI1XkEyXkFqcGdeQXdvbmtpbQ@@._V1_.jpg"},"thumbnailUrl":"https://m.media-amazon.com/images/M/MV5BNDQ4NTRmN2ItYjgzMS00MzY3LWEwNmYtYmE2ODllZDdhNGI1XkEyXkFqcGdeQXdvbmtpbQ@@._V1_.jpg","url":"https://www.imdb.com/video/vi1032782617/","description":"A computer hacker learns from mysterious rebels about the true nature of his reality and his role in the war against its controllers. ","duration":"PT2M26S","uploadDate":"2008-12-19T07:12:53Z"},"actor":[{"@type":"Person","url":"/name/nm0000206/","name":"Keanu Reeves"},{"@type":"Person","url":"/name/nm0000401/","name":"Laurence Fishburne"},{"@type":"Person","url":"/name/nm0005251/","name":"Carrie-Anne Moss"}],"director":[{"@type":"Person","url":"/name/nm0905154/","name":"Lana Wachowski"},{"@type":"Person","url":"/name/nm0905152/","name":"Lilly Wachowski"}],"creator":[{"@type":"Organization","url":"/company/co0002663/"},{"@type":"Organization","url":"/comp ...

# %% [markdown]
# We've now successfully obtained the HTML page corresponding to movie The Matrix. We now need to extract the relevant information from the page. Examining the HTML above, we notice that the title of the movie is contained within the first set of \<title\> tags (see \<title\>The Matrix (1999) - IMDb\</title\> in the HTML above). Therefore, we can now use soup.find('title'), which extracts the string contained within the first pair of \<title\> tags, to extract the title of the movie.

# %%
soup = BeautifulSoup(html, 'html.parser')

# extract the movie title
title = soup.find('title').text

# print the extracted data
print(f'Title: {title}')
# Out:
# Title: The Matrix (1999) - IMDb

# %% [markdown]
# To get the movie title without the "- IMDb" at the end, we can do the following:

# %%
title.split(' - ')[0]
# Out:
# ['The Matrix (1999)', 'IMDb']

# %% [markdown]
# Now that we've determined the process for extracting a movie title from an IMDb page, we can repeat it for other movies such as Avatar:

# %%
url = 'https://www.imdb.com/title/tt0499549/'
response = requests.get(url, headers=headers)
html = response.content

soup = BeautifulSoup(html, 'html.parser')

# extract the movie title
title = soup.find('title').text.split(' - ')[0]

# print the extracted data
print(f'Title: {title}')
# Out:
# Title: Avatar (2009)

# %% [markdown]
# #### Chrome Inspect Tool

# %% [markdown]
# To help us determine the HTML tags, we can use the Inspect tool in Google Chrome.
#
# First, we can go to CNN.com in a web browser and right-click on the page to bring up the context menu. From there, we can select "Inspect" to open up the developer tools in the browser.
#
# Once we have the developer tools open, we can use the mouse cursor to hover over different elements on the page and see how they are structured in the HTML code. We can also use the "Select element" tool (which looks like a cursor with a box around it) to click on an element and see its HTML code highlighted in the developer tools.
#
# For example, let's say we want to extract the headlines from the front page of CNN.com. Using the "Select element" tool, we can click on one of the headlines and see its HTML code highlighted in the developer tools. We can see that the headline is contained within an \<span\> tag with the "data-editable" attribute set to "headline".
#
# We can use Beautiful Soup to extract all of the headlines from the page by finding all of the \<span\> tags with that class with the "data-editable" attribute set to "headline" and extracting their text:

# %%
# Make a request to the CNN website
response = requests.get('https://www.cnn.com/')

# Create a BeautifulSoup object from the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find all the headline elements using the 'span' tag and 'data-editable' attribute
headline_elements = soup.find_all('span', {'data-editable': 'headline'})

# Extract the text content of each headline element
headlines = [element.text.strip() for element in headline_elements]

# Print the headlines
print(headlines)
# Out:
# ['Ukraine', 'Escaped inmates captured', 'Hunter Biden', 'Jamie Foxx', '‘Star Wars’ timeline', 'Coronation', 'Axe Files', 'A jury found them guilty for their role in trying to forcibly prevent the peaceful transfer of power from then-President Donald Trump to Joe Biden after the 2020 election', 'Proud Boys were ‘Donald Trump’s army,’ prosecutor said in closing arguments of seditious conspiracy trial', 'Proud Boy testified that talk of ‘stacking bodies’ was locker-room banter', 'Florida man charged with throwing explosive at Capitol riot', 'Former FBI supervisor arrested on January 6-related charges allegedly encouraged mob to ‘kill’ police', 'The only thing that makes sense about the drone attack on the Kremlin', 'Messages on Russian drones appear to reference alleged Putin assassination attempt', 'What we know about the murky drone attack and the questions that remain', 'CNN military analyst breaks down alleged Kremlin drone strike video', 'First Horizon stock tumbles after TD Bank merger collapses', 'The question everyone is asking about how to afford a home after rate hike', 'Doctors performed brain surgery on a baby before she was born, and now she’s thriving', 'Jon Bon Jovi has no issue with his son being engaged to Millie Bobby Brown', 'Olympic gold medalist dies at 32', 'Shohei Ohtani joins Babe Ruth in the MLB history books after latest feat', 'This Y2K pastime is becoming a big hit among South Korean youth', 'Woman fails to grab stroller rolling toward traffic. Then this happens', 'The ‘Star Wars’ timeline is confusing. Here’s when everything from the original trilogy to ‘The Mandalorian’ takes place', 'May the 4th be with you: 4 ways to celebrate ‘Star Wars Day’', 'Teen’s prom entrance steals the show', 'How the Atlanta mass shooting suspect was captured', 'Wife of NFL player Shaquil Barrett speaks out for first time since death of two-year-old daughter', 'Last of 4 escaped Mississippi inmates captured', 'What this preschool teacher carries with her at all times in case of a school shooting', 'After four horses die, home of Kentucky Derby calls circumstances ‘troubling’', '3 suspected of killing Colorado woman by hurling a large rock at her car are charged', 'Manhattan DA investigating death of man seen on video being put in a chokehold on NYC subway', 'Clinical trial: Alzheimer’s drug slows down cognitive decline by 35%', '‘This is how people are expected to live now’ in America’s mass shooting reality', 'Trump doesn’t plan to put on a defense case in E. Jean Carroll trial, his lawyer says', 'Host loses it as TV debate interrupted. See what happened', 'A Tyson Foods worker was trapped inside a poultry plant while toxic gas ravaged her eyes and lungs. It wasn’t an isolated incident', '10-year-old children were found working at a Louisville McDonald’s until 2 a.m.', 'Iowa lawmakers pass legislation to roll back child labor protections', 'Autoworkers union holding off endorsing Biden', 'TV and film writers are fighting to save their jobs from AI. They won’t be the last', 'Teachers in Oakland, California, are set to strike Thursday over contract talks', 'Quinta Brunson, Bowen Yang and Jay Leno show support for writers on strike', 'Podcast: Can an intimate relationship with an AI chatbot cure loneliness? For one woman, it’s helped.', 'Special counsel probing Trump Organization’s handling of Mar-a-Lago surveillance footage', 'Hunter Biden wants to reduce his $20,000-a-month child support payments. What’s next in the legal saga', 'Top Republicans demand FBI document they claim describes ‘alleged criminal scheme’ related to Biden', 'Priceless symbols to watch out for during King Charles’ III’s coronation', 'Look up to the sky for 3 space events this weekend', 'What’s the healthiest cheese? The best options, according to experts', '‘Brad or Ben’: Gwyneth Paltrow compares sex with her famous exes', 'Why these bank stocks aren’t getting crushed', 'These popular board games are getting revamped for older adults', 'TV and film wr ...

# %% [markdown]
# #### Further Examples
#
# We go through some examples to illustrate some common HTML tags and how to use them to extract information.

# %% [markdown]
# #### Example 1: Extracting Links

# %%
url = 'https://www.tasnimnews.com/fa'
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')
links = soup.find_all('a')

for link in links:
    href = link.get('href')
    if href and href.startswith('http'):
        print(href)
# Out:
# https://t.me/Tasnimnews
# https://www.instagram.com/tasnimnews_fa/
# https://twitter.com/Tasnimnews_Fa
# http://www.aparat.com/tasnim.video
# https://splus.ir/tasnimnews
# https://profile.igap.net/tasnimnews
# https://gap.im/join/nZrdWLo9xXy4LCIQ4wXsDLY7PQWjGpIgtu0cxJ3ZhWz
# https://ble.ir/tasnimnews
# https://rubika.ir/tasnimnews
# https://eitaa.com/tasnimnews
# https://t.me/Tasnimnews
# https://www.instagram.com/tasnimnews_fa/
# https://twitter.com/Tasnimnews_Fa
# http://www.aparat.com/tasnim.video
# https://splus.ir/tasnimnews
# https://profile.igap.net/tasnimnews
# https://gap.im/join/nZrdWLo9xXy4LCIQ4wXsDLY7PQWjGpIgtu0cxJ3ZhWz
# https://ble.ir/tasnimnews
# https://rubika.ir/tasnimnews
# https://eitaa.com/tasnimnews
# http://creativecommons.org/licenses/by/4.0/
# http://www.tasnimnews.com
# http://creativecommons.org/licenses/by/4.0/

# %% [markdown]
# This code uses BeautifulSoup to parse the HTML code of the ISNA news agency website and find all the \<a\> elements. It then extracts the href attribute of each link and prints it, but only if it starts with "http", to exclude internal links.

# %% [markdown]
# #### Example 2: Extracting Images

# %%
url = 'https://www.tasnimnews.com/fa'
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')
images = soup.find_all('img')

for image in images:
    src = image.get('src')
    if src and src.startswith('http'):
        print(src)
# Out:
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/18/1402021815342899127532583.jpeg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1401/11/30/1401113021073267127094812.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/01/03/1402010312211070927284182.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/01/24/1402012414513891727382192.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/18/1402021813064847027531212.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/18/1402021816545373627533312.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1394/12/10/139412101603505917247702.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1399/09/10/1399091012115956621719302.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/17/1402021713475248827526362.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/01/1402020114414992627439572.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1401/11/25/1401112513041738327060972.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1401/11/19/1401111914423893727008132.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1400/03/05/1400030513390515122856832.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1401/08/02/1401080212384361126297962.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1400/11/23/1400112308574197024748962.jpeg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/01/26/1402012610224190627403872.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/18/1402021817254892827533542.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1400/08/17/1400081710491595424004102.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1401/10/05/1401100511314444526712762.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1400/11/13/1400111313263231524669382.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/17/1402021712410276027525803.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/17/1402021715152387527527182.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/15/1402021503444989727514152.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/16/1402021614483960327521602.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/11/140202111434284727495812.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/17/1402021709255576327524892.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1401/11/11/1401111113435164026941032.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/09/1402020913531956827482472.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1394/10/26/13941026120615946912592.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1397/12/02/1397120214090247116716932.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/13/1402021316085461327509643.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/13/1402021315564312727509482.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/01/1402020120003797127439932.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/17/1402021718402285727528893.png
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/16/1402021616094888027522483.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/16/1402021612463997727520323.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/14/1402021410495945227511223.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1401/11/11/140111111049268426939534.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1401/11/29/1401112911545582627084254.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/18/14020218101029679275301410.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1400/11/09/1400110911495213224635704.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1401/05/09/1401050915073946325776214.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/17/1402021710504426027525304.jpeg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1399/03/19/1399031920554992420559864.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Image/1402/02/18/1402021809205743827529894.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Ads/1400/03/03/140003031112191602283879.gif
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Ads/1401/10/20/140110201402153472681658.gif
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Ads/1401/12/16/140112160846387812718354.gif
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Ads/1401/11/02/140111021727581132688440.gif
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Ads/1401/09/12/140109120936442612657904.gif
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Ads/1401/09/24/140109241511451582665137.gif
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Ads/1401/12/23/140112231054344622723312.gif
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Ads/1401/12/07/140112071000264382713220.jpg
# https://newsmedia.tasnimnews.com/Tasnim/Uploaded/Ads/1401/06/08/140106081039574752599199.gif

# %% [markdown]
# This code uses BeautifulSoup to parse the HTML code of the Fars News Agency website and find all the <img> elements. It then extracts the src attribute of each image and prints it, but only if it starts with "http", to exclude internal images.

# %% [markdown]
# #### Example 3: Extracting Text

# %%
url = 'https://www.cnn.com/'
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')
text = soup.get_text()

print(text)
# Out:
#
#
#
#
#
#
#
#
#
# Breaking News, Latest News and Videos | CNN
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# CNN values your feedback
#
#
#
#
#                                                         1. How relevant is this ad to you?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 2. Did you encounter any technical issues?
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                         Video player was slow to load content
#
#
#
#
#                                                                         Video content never loaded
#
#
#
#
#                                                                         Ad froze or did not finish loading
#
#
#
#
#                                                                         Video content did not start after ad
#
#
#
#
#                                                                         Audio on ad was too loud
#
#
#
#
#                                                                         Other issues
#
#
#
#
#
#
#                                                                         Ad never loaded
#
#
#
#
#                                                                         Ad prevented/slowed the page from loading
#
#
#
#
#                                                                         Content moved around while ad loaded
#
#
#
#
#                                                                         Ad was repetitive to ads I've seen previously
#
#
#
#
#                                                                         Other issues
#
#
#
#
#
#
#
#
#
#
#
#
#                                                         Cancel
#
#
#                                                         Submit
#
#
#
#
#
#
# Thank You!
#
#                                         Your effort and contribution in providing this feedback is much
#                                         appreciated.
#
#
#                                         Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close icon
#
#
#
#
#
#
#
#
#
#
#
#
#
#                   US
#
#
#
#
#
#                   World
#
#
#
#
#
#                   Politics
#
#
#
#
#
#                   Business
#
#
#
#
#
#                   Opinion
#
#
#
#
#
#                   Health
#
#
#
#
#
#                   Entertainment
#
#
#
#
#
#                   Style
#
#
#
#
#
#                   Travel
#
#
#
#
#
#                   Sports
#
#
#
#
#
#                   Video
#
#
#
#
#                   More
#
#
#
#                     US
#
#
#                     World
#
#
#                     Politics
#
#
#                     Business
#
#
#                     Opinion
#
#
#                     Health
#
#
#                     Entertainment
#
#
#                     Style
#
#
#                     Travel
#
#
#                     Sports
#
#
#                     Video
#
#
#
#
#
#
#
#
#             Audio
#
#
#             Live TV
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Log In
#
#
#
#
#       My Account
#
#
#
#
#
#           Settings
#
#
#
#
#           Log Out
#
#
#
#
#
# Your CNN account
# Log in to your CNN account
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Log In
#
#
#
#
#       My Account
#
#
#
#
#
#           Settings
#
#
#
#
#           Log Out
#
#
#
#
#
# Your CNN account
# Log in to your CNN account
#
#
#
#
#
#
#             Live TV
#
#
#             Audio
#
#
#
#
# Edition
#
#
#                   US
#
#
#
#
#                   International
#
#
#
#
#                   Arabic
#
#
#
#
#                   Español
#
#
#
#
#
#                 Edition
#
#
#
#
#
#                   US
#
#
#
#
#                   International
#
#
#
#
#                   Arabic
#
#
#
#
#                   Español
#
#
#
#
#
#
#
#
#
#
#         US
#
#
#
#
#             Crime + Justice
#
#
#
#
#             Energy + Environment
#
#
#
#
#             Extreme Weather
#
#
#
#
#             Space + Science
#
#
#
#
#
#
#         World
#
#
#
#
#             Africa
#
#
#
#
#             Americas
#
#
#
#
#             Asia
#
#
#
#
#             Australia
#
#
#
#
#             China
#
#
#
#
#             Europe
#
#
#
#
#             India
#
#
#
#
#             Middle East
#
#
#
#
#             United Kingdom
#
#
#
#
#
#
#         Politics
#
#
#
#
#             SCOTUS
#
#
#
#
#             Congress
#
#
#
#
#             Facts First
#
#
#
#
#             2020 Election
#
#
#
#
#
#
#         Business
#
#
#
#
#             Tech
#
#
#
#
#             Media
#
#
#
#
#             Calculators
#
#
#
#
#             Video
#
#
#
#
#
#
#         Markets
#
#
#
#
#             Pre-markets
#
#
#
#
#             After-Hours
#
#
#
#
#             Market Movers
#
#
#
#
#             Fear & Greed
#
#
#
#
#             World Markets
#
#
#
#
#             Investing
#
#
#
#
#             Markets Now
#
#
#
#
#             Before the Bell
#
#
#
#
#             Nightcap
#
#
#
#
#
#
#         Opinion
#
#
#
#
#             Political Op-Eds
#
#
#
#
#             Social Commentary
#
#
#
#
#
#
#         Health
#
#
#
#
#             Life, But Better
#
#
#
#
#             Fitness
#
#
#
#
#             Food
#
#
#
#
#             Sleep
#
#
#
#
#             Mindfulness
#
#
#
#
#             Relationships
#
#
#
#
#
#
#         Entertainment
#
#
#
#
#             Movies
#
#
#
#
#             Television
#
#
#
#
#             Celebrity
#
#
#
#
#
#
#         Tech
#
#
#
#
#             Innovate
#
#
#
#
#             Gadget
#
#
#
#
#             Foreseeable Future
#
#
#
#
#             Mission: Ahead
#
#
#
#
#             Upstarts
#
#
#
#
#             Work Transformed
#
#
#
#
#             Innovative Cities
#
#
#
#
#
#
#         Style
#
#
#
#
#             Arts
#
#
#
#
#             Design
#
#
#
#
#             Fashion
#
#
#
#
#             Architecture
#
#
#
#
#             Luxury
#
#
#
#
#             Beauty
#
#
#
#
#             Video
#
#
#
#
#
#
#         Travel
#
#
#
#
#             Destinations
#
#
#
#
#             Food & Drink
#
#
#
#
#             Stay
#
#
#
#
#             Videos
#
#
#
#
#
#
#         Sports
#
#
#
#
#             Pro Football
#
#
#
#
#             College Football
#
#
#
#
#             Basketball
#
#
#
#
#             Baseball
#
#
#
#
#             Soccer
#
#
#
#
#             Olympics
#
#
#
#
#             Hockey
#
#
#
#
#
#
#         Videos
#
#
#
#
#             Live TV
#
#
#
#
#             Digital Studios
#
#
#
#
#             CNN Films
#
#
#
#
#             HLN
#
#
#
#
#             TV Schedule
#
#
#
#
#             TV Shows A-Z
#
#
#
#
#             CNNVR
#
#
#
#
#
#
#         CNN Underscored
#
#
#
#
#             Electronics
#
#
#
#
#             Fashion
#
#
#
#
#             Beauty
#
#
#
#
#             Health & Fitness
#
#
#
#
#             Home
#
#
#
#
#             Reviews
#
#
#
#
#             Deals
#
#
#
#
#             Money
#
#
#
#
#             Gifts
#
#
#
#
#             Travel
#
#
#
#
#             Outdoors
#
#
#
#
#             Pets
#
#
#
#
#             CNN Store
#
#
#
#
#
#
#         Coupons
#
#
#
#
#
#
#         More
#
#
#
#
#             Photos
#
#
#
#
#             Longform
#
#
#
#
#             Investigations
#
#
#
#
#             CNN Profiles
#
#
#
#
#             CNN Leadership
#
#
#
#
#             CNN Newsletters
#
#
#
#
#             Work for CNN
#
#
#
#
#
#
#
#
# Follow CNN
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Live Updates: Ukraine
#
#
#
#
#
#
#
#
# Texas mall shooting
#
#
#
#
#
#
#
#
# Trending: ‘Stranger Things’ filming halt
#
#
#
#
#
#
#
#
# James Harden
#
#
#
#
#
#
#
#
# India houseboat accident
#
#
#
#
#
#
#
#
# Podcast: One Thing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Texas gunman was wearing insignia associated with extremist groups
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# •Live Updates
#
#
#
#
# Joe Raedle/Getty Images
#
#
#
#
#
#
#
#
# Authorities investigating the mall shooter’s motive unearthed an extensive social media presence, including neo-Nazi and White supremacist-related posts they believe he shared, a source says
#
#
#
#
#
#
#
#
#
# Video captures moment gunman pulls into parking lot at Texas mall
#
#
#
#
#
#
#
#
# This is how many mass shootings there have been so far this year
#
#
#
#
#
#
#
#
# A security guard and an engineer who was shopping with a friend are among the 8 killed in the Texas mall shooting. What we know about the victims
#
#
#
#
#
#
#
#
# Analysis: Texas tragedies make it clear that fractured politics have failed to fix two of the nation’s rawest divides
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# •Live Updates
#
#
#
#
# Roman Pilipey/Getty Images
#
#
#
#
#
#
#
#
# Russian oligarch criticizes ‘terrible’ war in Ukraine
#
#
#
#
#
#
#
#
# Russia is sending museum pieces into war, but experts say they may still be effective
#
#
#
#
#
#
#
#
#
# Wagner chief backtracks on threat to Putin’s military leaders. Hear why
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Evelyn Hockstein/Reuters
#
#
#
#
#
#
#
#
# ‘Everything is on the table’ in response to Clarence Thomas revelations, Durbin says
#
#
#
#
#
#
#
#
# Chief Justice Roberts punts on request to investigate Thomas
#
#
#
#
#
#
#
#
#
# ‘It embarrasses me’: Senate Judiciary chair on Thomas revelations
#
#
#
#
#
#
#
#
# Opinion: The only way to get to the truth of the Clarence Thomas scandal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# •Video
#
#
#
#
#
#
#
# Writers Guild VP calls out 'miscalculation' studio executives are making
#
#
#                             03:36
#
#  - Source:
#                 CNN
#
#
#
#
#
#
#
#
#
# Video: Writers Guild VP calls out ‘miscalculation’ studio executives are making
#
#
#
#
#
#
#
#
# Dianna Agron responds to decade-long speculation about Taylor Swift relationship
#
#
#
#
#
#
#
#
# Tom Cruise pilots ‘Top Gun: Maverick’ jet during MTV awards acceptance speech
#
#
#
#
#
#
#
#
# ‘You have to be prepared to die,’ says German who holds the world record for the biggest wave ever surfed
#
#
#
#
#
#
#
#
#
# Pop star’s struggle to find her seat at King Charles’ coronation goes viral
#
#
#
#
#
#
#
#
# Analysis: Kids need to gain weight during adolescence. Here’s why
#
#
#
#
#
#
#
#
#
# Oprah warns against imposter syndrome during captivating speech
#
#
#
#
#
#
#
#
#
# Dad knocks out umpire at son’s baseball game
#
#
#
#
#
#
#
#
# Max Verstappen booed before and after race in Miami
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             More top stories
#
#
#
#
#
#
#
#
#
# CNN Exclusive: Nearly 610,000 public sector workers got student loan forgiveness after Biden loosened the rules
#
#
#
#
#
#
#
#
#
# Biden is asked why an 82-year-old is best fit for president. Hear his response
#
#
#
#
#
#
#
#
# The Fed could be on the verge of repeating its 1970s mistake, Fed historian says
#
#
#
#
#
#
#
#
# A huge homeless camp will be cleared after neighbors sued. What happens to its vulnerable residents is an open question
#
#
#
#
#
#
#
#
# Oakland Athletics’ announcer suspended indefinitely after using racial slur
#
#
#
#
#
#
#
#
# Tiger Woods is accused of sexual harassment by ex-girlfriend, according to court document
#
#
#
#
#
#
#
#
# More than 400 dead in flooding in Democratic Republic of Congo
#
#
#
#
#
#
#
#
# El Paso facing an unsustainable situation this week with Title 42 expiration, advocate says
#
#
#
#
#
#
#
#
# All but six Senate Republicans have vowed to oppose debt ceiling increase without spending cuts
#
#
#
#
#
#
#
#
#
# An agitated Trump appears in newly released deposition tapes
#
#
#
#
#
#
#
#
# Closing arguments set for Monday morning in E. Jean Carroll civil rape trial against Donald Trump
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Britain's first coronation in 70 years
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leon Neal/AFP/Pool/Getty Images
#
#
#
#
#
#
#
#
# Prince William pays tribute to King Charles at coronation concert
#
#
#
#
#
#
#
#
#
# ‘Not my King’: Hear why these Brits protested the coronation
#
#
#
#
#
#
#
#
# Dancing royals, ‘The Muppets’ and Tom Cruise: The best moments from the coronation concert
#
#
#
#
#
#
#
#
# The symbolism behind Kate and Charlotte’s coronation outfits
#
#
#
#
#
#
#
#
# Opinion: What King Charles should do now
#
#
#
#
#
#
#
#
#
# Here’s what’s interesting about where Prince Harry was seated
#
#
#
#
#
#
#
#
# Prince Harry immediately flew back to California
#
#
#
#
#
#
#
#
#
# In pictures: The coronation of King Charles III
#
#
#
#
#
#
#
#
# The King’s coronation brought in far fewer viewers than the Queen’s funeral
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# CNN
#
#
#
#
#
#
#
#
# Podcast: Can an intimate relationship with an AI chatbot cure loneliness? For one woman, it’s helped.
#
#
#           Mar 26, 2023
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             In the spotlight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Courtesy Netflix
#
#
#
#
#
#
#
#
# ‘Stranger Things’ filming halted because of writers’ strike
#
#
#
#
#
#
#
#
# Pete Davidson was set to return as host for ‘SNL.’ Here’s why it didn’t happen
#
#
#
#
#
#
#
#
# Review: Shiv and Tom steal the show as ‘Succession’ preps for a merger
#
#
#
#
#
#
#
#
# These ‘Peak TV’ shows changed everything. Did your favorite make the list?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Check these out
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Matt Slocum/AP
#
#
#
#
#
#
#
#
# James Harden fulfills promise to Michigan State shooting survivor; scores 42 points in 76ers’ Game 4 win over Celtics
#
#
#
#
#
#
#
#
#
#
#
#
#
# Courtesy Taylor Richard
#
#
#
#
#
#
#
#
# Chinese postpartum confinement is gaining Western appeal
#
#
#
#
#
#
#
#
#
#
#
#
#
# @PGATOUR / Twitter
#
#
#
#
#
#
#
#
# Rickie Fowler picks up snake with golf club at Wells Fargo Championship
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# •Video
#
#
#
#
#
#
#
#
#
#
# Woman fails to grab out-of-control stroller rolling toward traffic. Then this happens
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             CNN Business
#
#
#
#
#
#
#
#
#
# All-you-can-eat buffet restaurants are back
#
#
#
#
#
#
#
#
# The Fed could be on the verge of repeating its 1970s mistake, Fed historian says
#
#
#
#
#
#
#
#
# Website wants to pay you $1,000 to watch all 10 ‘Fast and the Furious’ films. Here’s why
#
#
#
#
#
#
#
#
# Lulu who? A cult brand takes on the booming culture of ‘dupes’
#
#
#
#
#
#
#
#
# Where the jobs are: These are the industries that are hiring – and firing
#
#
#
#
#
#
#
#
#
#
# Latest in Markets
#
#
#
#
# DOW
#
#
#
#
# S&P 500
#
#
#
#
# NASDAQ
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             CNN Underscored
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Editor-tested
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Brett Ferdock/CNN
#
#
#
#
#
#
#
#
# Lululemon Align vs. Uniqlo Bra Top: We put these built-in bra tanks to the test
#
#
#
#
#
#
#
#
# The best true wireless earbuds of 2023
#
#
#
#
#
#
#
#
# The 41 best products we tried and loved in April
#
#
#
#
#
#
#
#
# We tested 6 grill brushes to see which was best. 1 came out on top, and it’s on sale now
#
#
#
#
#
#
#
#
# Adidas vs. Hoka: We put these favorite running shoes to the test
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Expert-backed guides
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Brett Ferdock/CNN Underscored
#
#
#
#
#
#
#
#
# The essentials list: HGTV stars Erin and Ben Napier share their home must-haves
#
#
#
#
#
#
#
#
# How to actually clean your oven, according to experts
#
#
#
#
#
#
#
#
# These are the 10 best deals to shop on Amazon this week
#
#
#
#
#
#
#
#
# The 20 best body scrubs and exfoliators, according to skin experts
#
#
#
#
#
#
#
#
# The 5 best balance transfer credit cards with a 0% APR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Shopping Recommendations
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Mike Andronico/CNN
#
#
#
#
#
#
#
#
# The AirPods Pro 2 are $1 away from their lowest price ever
#
#
#
#
#
#
#
#
# The best Mother’s Day gifts under $25 you can buy on Amazon
#
#
#
#
#
#
#
#
# The 46 best graduation gifts that are just as smart as they are
#
#
#
#
#
#
#
#
# The $10 Kitchen SinkShroom simply saves your drains
#
#
#
#
#
#
#
#
# Mother’s Day is this Sunday. Here are 56 thoughtful gifts the mom in your life will love
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Food and home
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Food Network
#
#
#
#
#
#
#
#
# How nutritionists fight sugar cravings
#
#
#
#
#
#
#
#
#
#
#
#
#
# Getty Images/iStockphoto
#
#
#
#
#
#
#
#
# Cleaning habits that are actually making your kitchen dirty
#
#
#
#
#
#
#
#
#
#
#
#
#
# Shutterstock/Andrei Kuzmik
#
#
#
#
#
#
#
#
# 6 ways to humidify your house (without a humidifier)
#
#
#
#
#
#
#
#
#
#
#
#
#
# Good Bones
#
#
#
#
#
#
#
#
# 10 tips for a happy life from ‘Good Bones’ renovator Tad Starsiak
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Opinion
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Alex Kent/AFP/Getty Images
#
#
#
#
#
#
#
#
# How we all played a role in Jordan Neely’s death on a subway train
#
#
#
#
#
#
#
#
# This is the verdict the Proud Boys fear most
#
#
#
#
#
#
#
#
# My family and I barely escaped
#
#
#
#
#
#
#
#
# For women, it’s past time to give up the ghost of equality
#
#
#
#
#
#
#
#
# Border surge is big test for Biden
#
#
#
#
#
#
#
#
# Whatever happened over Kremlin, one thing is certain
#
#
#
#
#
#
#
#
# We are weeks away from potential financial disaster
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Entertainment
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Warner Bros. Pictures
#
#
#
#
#
#
#
#
# Summer movie season is back and this year’s lineup is packed
#
#
#
#
#
#
#
#
# Johnny Weir really wants you to watch Eurovision
#
#
#
#
#
#
#
#
# Jeremy Renner sharing a new update on his recovery
#
#
#
#
#
#
#
#
# Analysis: ‘Fantastic Four’ can learn from ‘Guardians’
#
#
#
#
#
#
#
#
# Amazon moving forward with ‘Rings of Power’ production despite writers’ strike being underway
#
#
#
#
#
#
#
#
# ‘Peak TV’ shows that defined the 2010s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Travel
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Westend61/Getty Images
#
#
#
#
#
#
#
#
# Half the world relies on this staple. These are its most delicious preparations
#
#
#
#
#
#
#
#
# $2 billion airport could change aviation on this continent
#
#
#
#
#
#
#
#
# New hypersonic plane design promises Europe to Australia in under 5 hours
#
#
#
#
#
#
#
#
# It’s been called Japan’s most boring city. Here’s why you should visit
#
#
#
#
#
#
#
#
# Two strangers met while hiking and got engaged three weeks later. Here’s what happened next
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Style
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Andrew Kelly/Reuters
#
#
#
#
#
#
#
#
# Met Gala 2023 fashion: The best looks from the red carpet
#
#
#
#
#
#
#
#
# Remember when Prince bared his butt at the 1991 VMAs?
#
#
#
#
#
#
#
#
# World’s first 3D-printed mosque to be built in Dubai
#
#
#
#
#
#
#
#
# The US has a rich drag history. Here’s why the art form will likely outlast attempts to restrict it
#
#
#
#
#
#
#
#
# Judy Blume’s books were formative for generations of readers. Here’s why they endure
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Science and health
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# University of Michigan
#
#
#
#
#
#
#
#
# Scientists unlock new secrets from a male woolly mammoth tusk
#
#
#
#
#
#
#
#
# Buried treasure, including nearly 200 Roman coins, found in Italy
#
#
#
#
#
#
#
#
# Fossil site discovered in Wales reveals early life forms
#
#
#
#
#
#
#
#
# Webb telescope detects mysterious water vapor in a nearby star system
#
#
#
#
#
#
#
#
# Study: Foods packaged for kids are higher in sugar and lower in nutrition
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             World
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Arun Sankar/AFP/Getty Images
#
#
#
#
#
#
#
#
# Why has a state in India’s northeast exploded in ethnic unrest?
#
#
#
#
#
#
#
#
# Analysis: ‘A Trump tribute act’: Meet the commander-in-chief of Britain’s culture wars
#
#
#
#
#
#
#
#
# More than 29,000 people evacuated from communities throughout Alberta as wildfires rage in Canada
#
#
#
#
#
#
#
#
# Vietnam and Laos record their hottest temperatures ever as heat wave grips Southeast Asia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Politics
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Alex Wong/Getty Images
#
#
#
#
#
#
#
#
# Biden administration will propose rule requiring airlines to compensate passengers for canceled or delayed flights
#
#
#
#
#
#
#
#
# Top Republican investigating Biden administration withdrawal from Afghanistan threatens to hold Blinken in contempt of Congress
#
#
#
#
#
#
#
#
# Georgia’s GOP governor signs bill that could remove local prosecutors and DAs from their jobs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             US
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Andrew Savulich/New York Daily News/Tribune News Service/Getty Images
#
#
#
#
#
#
#
#
# Man who died last week after being held in a chokehold on a New York City subway was on a list of homeless people with dire needs
#
#
#
#
#
#
#
#
# Witnesses describe horrifying crash that left 8 dead outside a Texas shelter housing migrants
#
#
#
#
#
#
#
#
# Senior Treasury officials reiterate dire warnings if debt ceiling isn’t lifted, pour cold water on invoking the 14th Amendment
#
#
#
#
#
#
#
#
# Suspect arrested after 1 killed, 6 injured in Mississippi restaurant shooting
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             CNN podcasts
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# CNN
#
#
#
#
#
#
#
#
# Inside the beginning of a border surge
#
#
#
#
#
#
#
#
# George Clooney opens up about his philanthropy
#
#
#
#
#
#
#
#
# Meet the designer responsible for Prince’s iconic looks
#
#
#
#
#
#
#
#
# Can marrying an AI chatbot cure loneliness?
#
#
#
#
#
#
#
#
# Rep. Katie Porter on how the Dems lost rural America
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Environment
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Alexis Rosenfeld/Getty Images
#
#
#
#
#
#
#
#
# Ocean temperatures are off the charts right now, and scientists are alarmed
#
#
#
#
#
#
#
#
# 21 critically endangered California condors have died from avian flu
#
#
#
#
#
#
#
#
# A surprising number of drifting sea creatures found living in the Great Pacific Garbage Patch
#
#
#
#
#
#
#
#
# Climate activists dye iconic Italian fountain water black
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Sports
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Noam Galai/Getty Images for Tribeca Festival
#
#
#
#
#
#
#
#
# Yankees legend Derek Jeter, wife Hannah welcome newborn son
#
#
#
#
#
#
#
#
# Dallas Stars cancel playoff watch party after Texas mall shooting
#
#
#
#
#
#
#
#
# Max Verstappen wins Miami grand prix
#
#
#
#
#
#
#
#
# Cavaliers governor’s son dies at age 26
#
#
#
#
#
#
#
#
# NBA legend Ray Allen graduates from UConn
#
#
#
#
#
#
#
#
# LeBron James’ son commits to play for USC
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Video
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Paid Content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             More from CNN
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Life, But Better
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Adobe Stock
#
#
#
#
#
#
#
#
# Marijuana may make sleep worse, especially for regular users, study finds
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# •Video
#
#
#
#
#
#
#
#
#
#
# Your snoring could be a sign of something more dangerous
#
#
#
#
#
#
#
#
#
#
#
#
#
# fizkes/Adobe Stock
#
#
#
#
#
#
#
#
# These simple daily activities can help ward off back pain
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Eva Longoria: Searching for Mexico
#
#
#
#
#
# Show all
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ramona Rosales/CNN
#
#
#
#
#
#
#
#
# Eva Longoria shares 5 essential Mexico experiences
#
#
#
#
#
#
#
#
#
#
#
#
#
# Douglas Peebles/Corbis Documentary RF/Getty Images
#
#
#
#
#
#
#
#
# These beautiful Mexican beach areas won’t be mobbed
#
#
#
#
#
#
#
#
#
#
#
#
#
# CNN
#
#
#
#
#
#
#
#
# This savory Mexican dish made with vanilla is a first for Eva Longoria
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Photos
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# •Gallery
#
#
#
#
# Andrew Matthews/Pool/AP
#
#
#
#
#
#
#
#
# In pictures: The coronation of King Charles III
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Emily Steinberger
#
#
#
#
#
#
#
#
# ‘This book is our memory’: A descendant of Holocaust survivors preserves her family’s history
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# •Gallery
#
#
#
#
# Rebecca Smeyne/The New York Times/Redux
#
#
#
#
#
#
#
#
# The week in 34 photos
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# •Gallery
#
#
#
#
# Bettmann Archive/Getty Images
#
#
#
#
#
#
#
#
# Harry Belafonte’s life in pictures
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Paid Partner Content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             In Case You Missed It
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# South Africa Tourism
#
#
#
#
#
#
#
#
# The country with epic hikes — and more than 3,700 trails
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fire kills at least 27 in Peruvian gold mine
#
#
#
#
#
#
#
#
# Loaf-size mission launches to improve hurricane forecasting
#
#
#
#
#
#
#
#
# A Chicago officer was shot and killed after completing her shift
#
#
#
#
#
#
#
#
# Child in Maine tests positive for measles, first case in state since 2019
#
#
#
#
#
#
#
#
# Father of high school baseball player arrested after knocking out umpire, sheriff says
#
#
#
#
#
#
#
#
# Opinion: Capped deposit insurance is destroying banks
#
#
#
#
#
#
#
#
# Drew Barrymore steps down from hosting MTV Movie & TV Awards in support of writers’ strike
#
#
#
#
#
#
#
#
# At least 8 fake electors have been granted immunity in the Georgia Trump investigation
#
#
#
#
#
#
#
#
# Buried treasure, including nearly 200 Roman coins, found in Italy
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Log In
#
#
#
#
#       My Account
#
#
#
#
#
#           Settings
#
#
#
#
#           Log Out
#
#
#
#
#
# Your CNN account
# Log in to your CNN account
#
#
#
#
#
#
#         Live TV
#
#
#         Audio
#
#
#
#
#
#
#
#         US
#
#
#
#
#             Crime + Justice
#
#
#
#
#             Energy + Environment
#
#
#
#
#             Extreme Weather
#
#
#
#
#             Space + Science
#
#
#
#
#
#
#         World
#
#
#
#
#             Africa
#
#
#
#
#             Americas
#
#
#
#
#             Asia
#
#
#
#
#             Australia
#
#
#
#
#             China
#
#
#
#
#             Europe
#
#
#
#
#             India
#
#
#
#
#             Middle East
#
#
#
#
#             United Kingdom
#
#
#
#
#
#
#         Politics
#
#
#
#
#             The Biden Presidency
#
#
#
#
#             Facts First
#
#
#
#
#             US Elections
#
#
#
#
#
#
#         Business
#
#
#
#
#             Tech
#
#
#
#
#             Media
#
#
#
#
#             Calculators
#
#
#
#
#             Videos
#
#
#
#
#
#
#         Markets
#
#
#
#
#             Pre-markets
#
#
#
#
#             After-Hours
#
#
#
#
#             Market Movers
#
#
#
#
#             Fear & Greed
#
#
#
#
#             World Markets
#
#
#
#
#             Investing
#
#
#
#
#             Markets Now
#
#
#
#
#             Before the Bell
#
#
#
#
#             Nightcap
#
#
#
#
#
#
#         Opinion
#
#
#
#
#             Political Op-Eds
#
#
#
#
#             Social Commentary
#
#
#
#
#
#
#         Health
#
#
#
#
#             Life, But Better
#
#
#
#
#             Fitness
#
#
#
#
#             Food
#
#
#
#
#             Sleep
#
#
#
#
#             Mindfulness
#
#
#
#
#             Relationships
#
#
#
#
#
#
#         Entertainment
#
#
#
#
#             Movies
#
#
#
#
#             Television
#
#
#
#
#             Celebrity
#
#
#
#
#
#
#         Tech
#
#
#
#
#             Innovate
#
#
#
#
#             Gadget
#
#
#
#
#             Foreseeable Future
#
#
#
#
#             Mission: Ahead
#
#
#
#
#             Upstarts
#
#
#
#
#             Work Transformed
#
#
#
#
#             Innovative Cities
#
#
#
#
#
#
#         Style
#
#
#
#
#             Arts
#
#
#
#
#             Design
#
#
#
#
#             Fashion
#
#
#
#
#             Architecture
#
#
#
#
#             Luxury
#
#
#
#
#             Beauty
#
#
#
#
#             Video
#
#
#
#
#
#
#         Travel
#
#
#
#
#             Destinations
#
#
#
#
#             Food & Drink
#
#
#
#
#             Stay
#
#
#
#
#             News
#
#
#
#
#             Videos
#
#
#
#
#
#
#         Sports
#
#
#
#
#             Pro Football
#
#
#
#
#             College Football
#
#
#
#
#             Basketball
#
#
#
#
#             Baseball
#
#
#
#
#             Soccer
#
#
#
#
#             Olympics
#
#
#
#
#             Hockey
#
#
#
#
#
#
#         Videos
#
#
#
#
#             Live TV
#
#
#
#
#             Digital Studios
#
#
#
#
#             CNN Films
#
#
#
#
#             HLN
#
#
#
#
#             TV Schedule
#
#
#
#
#             TV Shows A-Z
#
#
#
#
#             CNNVR
#
#
#
#
#
#
#         Audio
#
#
#
#
#
#
#         CNN Underscored
#
#
#
#
#             Electronics
#
#
#
#
#             Fashion
#
#
#
#
#             Beauty
#
#
#
#
#             Health & Fitness
#
#
#
#
#             Home
#
#
#
#
#             Reviews
#
#
#
#
#             Deals
#
#
#
#
#             Money
#
#
#
#
#             Gifts
#
#
#
#
#             Travel
#
#
#
#
#             Outdoors
#
#
#
#
#             Pets
#
#
#
#
#             CNN Store
#
#
#
#
#
#
#         Coupons
#
#
#
#
#
#
#         Weather
#
#
#
#
#             Climate
#
#
#
#
#             Storm Tracker
#
#
#
#
#             Wildfire Tracker
#
#
#
#
#             Video
#
#
#
#
#
#
#         More
#
#
#
#
#             Photos
#
#
#
#
#             Longform
#
#
#
#
#             Investigations
#
#
#
#
#             CNN Profiles
#
#
#
#
#             CNN Leadership
#
#
#
#
#             CNN Newsletters
#
#
#
#
#             Work for CNN
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Audio
#
#
#             Live TV
#
#
#
# Follow CNN
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Log In
#
#
#
#
#       My Account
#
#
#
#
#
#           Settings
#
#
#
#
#           Log Out
#
#
#
#
#
# Your CNN account
# Log in to your CNN account
#
#
#
#
#
#
#
#
#
#           Terms of Use
#
#
#           Privacy Policy
#
#
#
#
#           Ad Choices
#
#
#           Accessibility & CC
#
#
#           About
#
#
#           Newsletters
#
#
#           Transcripts
#
#
# © 2023 Cable News Network. A Warner Bros. Discovery Company. All Rights Reserved.  CNN Sans ™ & © 2016 Cable News Network.

# %% [markdown]
# This code uses BeautifulSoup to parse the HTML code of the CNN website and extract all the text content. We then print the text, which includes all the visible text on the page as well as any text within HTML elements.
